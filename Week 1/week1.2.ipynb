# %%
import pandas as pd

# %%
df = pd.read_csv('V5.csv')

# %%
even_indexed_rows = df.iloc[::2]

# %%
even_indexed_rows
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 2     2009-01-02  2009   Waterbury          55720.0    140000.0
# 4     2009-01-02  2009  Bridgeport         112351.0    210000.0
# 6     2009-01-02  2009     Norwalk         571060.0   1000000.0
# 8     2009-01-02  2009         NaN         603540.0   1680000.0
# ...          ...   ...         ...              ...         ...
# 9990  2022-09-30  2022         NaN         352030.0    700000.0
# 9992  2022-09-30  2022   Fairfield              NaN    680000.0
# 9994  2022-09-30  2022         NaN         155550.0    215000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %%
even_indexed_rows.iloc[0, 3]
# Out:
# 111440.0

# %%
even_indexed_rows.iloc[332, 3]
# Out:
# 256200.0

# %%
odd_indexed_rows = df.iloc[1::2]

# %%
odd_indexed_rows
# Out:
#             Date  Year       Locality  Estimated Value  Sale Price  \
# 1     2009-01-02  2009     Bridgeport         124670.0    150000.0
# 3     2009-01-02  2009     Bridgeport        4775276.0    272900.0
# 5     2009-01-02  2009      Greenwich        2868880.0   3300000.0
# 7     2009-01-02  2009      Greenwich         592760.0    920000.0
# 9     2009-01-02  2009     Bridgeport         137901.0    245000.0
# ...          ...   ...            ...              ...         ...
# 9991  2022-09-30  2022        Norwalk         344270.0    512500.0
# 9993  2022-09-30  2022  West Hartford         121870.0    235000.0
# 9995  2022-09-30  2022     Bridgeport         153660.0    322000.0
# 9997  2022-09-30  2022      Waterbury          83210.0    170000.0
# 9999  2022-09-30  2022        Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 1        Two Family          Duplex          4              3       1241.0
# ...

# %%
odd_indexed_rows.shape
# Out:
# (5000, 12)

# %%
odd_indexed_rows.iloc[332, 3]
# Out:
# 352940.0

# %%
odd_indexed_rows.iloc[100, 5]
# Out:
# 'Single Family'

# %%
odd_indexed_columns = df.iloc[:, 1::2]

# %%
odd_indexed_columns.iloc[100, 5]
# Out:
# 'West'

# %%
even_indexed_columns = df.iloc[:, ::2]

# %%
even_indexed_columns
# Out:
#             Date    Locality  Sale Price     Residential  num_bathrooms  \
# 0     2009-01-02   Waterbury    185000.0  Detached House              3
# 1     2009-01-02  Bridgeport    150000.0          Duplex              3
# 2     2009-01-02   Waterbury    140000.0  Detached House              2
# 3     2009-01-02  Bridgeport    272900.0  Detached House              1
# 4     2009-01-02  Bridgeport    210000.0  Detached House              2
# ...          ...         ...         ...             ...            ...
# 9995  2022-09-30  Bridgeport    322000.0  Detached House              3
# 9996  2022-09-30  Bridgeport    340000.0          Duplex              4
# 9997  2022-09-30   Waterbury    170000.0  Detached House              1
# 9998  2022-09-30         NaN    415000.0  Detached House              3
# 9999  2022-09-30     Norwalk    196000.0  Detached House              1
#
#       property_tax_rate
# 0              1.025953
# 1              1.025953
# 2              1.025953
# ...

# %%
even_indexed_columns.iloc[255, 3]
# Out:
# 'Detached House'

# %%
even_indexed_rows.iloc[255, 3]
# Out:
# 798070.0

# %%
df
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 1     2009-01-02  2009  Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009   Waterbury          55720.0    140000.0
# 3     2009-01-02  2009  Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009  Bridgeport         112351.0    210000.0
# ...          ...   ...         ...              ...         ...
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9997  2022-09-30  2022   Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
# 9999  2022-09-30  2022     Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %%
most_recent_years = sorted(df['Year'].unique(), reverse=True)[:6]
filtered_df = df[df['Year'].isin(most_recent_years)]
len(filtered_df)
# Out:
# 4749

# %%
((df['num_rooms'] == 3) & (df['num_bathrooms'] == 3)).sum()
# Out:
# 2730

# %%
((df['num_rooms'] == 3) | (df['num_bathrooms'] == 3)).sum()
# Out:
# 8591

# %%
df
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 1     2009-01-02  2009  Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009   Waterbury          55720.0    140000.0
# 3     2009-01-02  2009  Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009  Bridgeport         112351.0    210000.0
# ...          ...   ...         ...              ...         ...
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9997  2022-09-30  2022   Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
# 9999  2022-09-30  2022     Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %%
((df['Year'] == 2022) & (df['Locality'] == 'Greenwich') & (df['num_rooms'] == 3) & ((df['Face'] == 'North') | (df['Face'] == 'East'))).sum()
# Out:
# 42

# %%
average_sale_price = df.groupby('Locality')['Sale Price'].mean()
highest_avg_sale_price_locality = average_sale_price.idxmax()
highest_avg_sale_price_locality
# Out:
# 'Greenwich'
